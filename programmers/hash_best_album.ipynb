# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./png/best_album1.png')
img2 = mpimg.imread('./png/best_album2.png')
fig = plt.figure(figsize=(30, 30))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# 두개씩 모아
genres = ['classic','pop','classic','classic','pop']
plays = [500,600,150,800,25000]

dic = dict()


for g,p in zip(genres, plays):
    
    try:
        dic[g] += p
    except:
        dic[g] = p
    
    
answer = []

while dic:
    which = [[plays[idx],idx] for idx,x in enumerate(genres) if max(dic) == x]
    print(dic)
    del dic[max(dic)]
    
    
    for _ in range(2):
        try:
            tmp_max = max(which, key=lambda x: x[0])
            answer.append(tmp_max[1])

            which.remove(tmp_max)
            
        except:
            break
    
    
#     cnt = 0

#     tmp_order= sorted(which, key=lambda x: x[0], reverse = True)
#     for _,j in tmp_order:
        
#         answer.append(j)
#         cnt += 1
        
        
#         if cnt == 2:
#             break
# Out:
# {'classic': 1450, 'pop': 25600}
# {'classic': 1450}

# %%
answer
# Out:
# [4, 1, 3, 0]

# %%
max(which, key=lambda x: x[0])
# Out:
# [800, 3]

# %%
dic
# Out:
# {'classic': 1450, 'pop': 25600}

# %%
which = [[plays[idx],idx] for idx,x in enumerate(genres) if max(dic) == x]
del dic[max(dic)]
# Out:
# 'pop'

# %%
which
# Out:
# [[600, 1], [25000, 4]]

# %%
answer = []

tmp_order= sorted(which, key=lambda x: x[0], reverse = True)
for _,j in tmp_order:
    answer.append(j)

# %%
answer
# Out:
# [4, 1]
