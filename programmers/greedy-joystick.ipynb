# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./png/greedy-joystick.png')
# img2 = mpimg.imread('./png/best_album2.png')
fig = plt.figure(figsize=(30, 30))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
# ax2 = fig.add_subplot(1,2,2)
# ax2.imshow(img2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
name = 'AAAAAA'

# %%
# let's make dictionary

check_name = 0
for i in name:
    if i == 'A':
        check_name += 1

if len(name) == check_name:
    return 0

dic = dict()
idx = 0
for i in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
    dic[str(i)] = min(idx, 26-idx)
    idx += 1
    

forward_name = name

# backward
backward_name = ""

for i in name[1:]:
    backward_name =  i + backward_name
backward_name = name[0] + backward_name
    

    
total_ls = []
for name_ in [forward_name, backward_name]:
# # 끝부분 A들을 하나로 합친다.
    switch = 'on'
    cnt = 1
    while True:
        if switch == 'off':
            break


        if name_[-cnt] == 'A':
            cnt += 1
        else:
            switch = 'off'
            break

    cnt -= 1
    
    
    
    
    
    tmp_name = name_[:-cnt]
    
    if len(tmp_name) == 0:
        tmp_name = name_
        
    
    total = 0
    for alphabet in tmp_name:
        total += dic[alphabet]
        
    total += len(tmp_name) - 1
    total_ls.append(total)
    
answer = min(total_ls)
# Out:
#   File "<ipython-input-72-5678e1283ae6>", line 9
#     return 0
#     ^
# SyntaxError: 'return' outside function

# %%
forward_name
# Out:
# 'JEROEN'

# %%
backward_name
# Out:
# 'JNEORE'

# %%
total_ls
# Out:
# [-1, -1]

# %%
dic['B']
# Out:
# 1

# %%
len(tmp_name)
# Out:
# 0

# %%
total_ls
# Out:
# [56, 56]

# %%
cnt
# Out:
# 3

# %%
cnt = 1

# %%
name[-cnt]
# Out:
# 'A'

# %%
name[:-cnt]
# Out:
# 'JAN'

# %%
add
# Out:
# 25

# %%
number_to_add
# Out:
# [1]

# %%
name
# Out:
# 'JAN'

# %%
first = name[0]


reverse_name = ""
tmp_name = name[1:]
for i in tmp_name:
    reverse_name = i + reverse_name     

start = "A"*len(name)

# let's make dictionary
dic = dict()
idx = 0
for i in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
    dic[str(i)] = min(idx, 26-idx)
    idx += 1

    
number_A = [i for i in name if i == 'A']
number_add = len(name) + 1 - len(number_A) -2
    
forward = dic[first]
for i in tmp_name:    
    forward += dic[i]

backward = dic[first]
for i in reverse_name:
    backward += dic[i]
    
answer = min(forward, backward) + number_add

# %%
forward
# Out:
# 22

# %%
answer
# Out:
# 23

# %%
def solution(name):

    
    start = "A"*len(name)


    # let's make dictionary
    dic = dict()
    idx = 0
    for i in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
        dic[str(i)] = min(idx, 26-idx)
        idx += 1


    # forward
    forward = 0
    for i in name:
        forward += dic[i] + 1
    forward -= 1


    backward = 0
    for i in range(1,len(name)+1):
        backward += dic[name[-i]] + 1
    backward -= 1

    answer = min(forward, backward)
    
    return answer

# %%
backward_name
# Out:
# 'NAJ'

# %%
# backward name
backward_name = ""
for i in name:
    backward_name = backward_name + i

start = "A"*len(name)



# let's make dictionary
dic = dict()
idx = 0
for i in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ':
    dic[str(i)] = min(idx, 26-idx)
    idx += 1
dic['A'] = 1
    
    
# count num of A
num_A = [i for i in name if i == "A"]
    
if len(num_A) == 0:
    answer = len(name) - 1
    for i in name:
        answer += dic[i]
    return answer

else:
    tmp = len(name)-len(num_A)+1
    

test = 0
for i in name:
    test += dic[i]
# # forward
# forward = 0
# for i in name:
#     forward += dic[i] + 1
# forward -= 1
    
    
# backward = 0
# for i in range(1,len(name)+1):
#     backward += dic[name[-i]] + 1
# backward -= 1

# answer = min(forward, backward)
# forward
# count num of A
# num_A = [i for i in name if i == "A"]
# # count numn of move
# if len(num_A) == 0:
#     num_add = len(name) - 1
# elif len(num_A) == 1:
#     num_add = len(name) - 2
# else:
#     num_add = len(name) - len(num_A)


# for i in name:
#     num_add += dic[i]
    
# num_add
# # backward
# if len(num_A) == 0:
#     num_add = len(name) - 1
# else:
#     num_add = len(name) - 2
    
# for i in reverse_name:
#     num_add += dic[i]
    
# backward = num_add
# min(forward, backward)

# %%
test
# Out:
# 51

# %%
forward
# Out:
# 8

# %%
for i in reverse_name:
    print(i)
# Out:
# Z
# A
# A
# A
# A
# A

# %%
k = 0
for i in name:
    k += dic[i]
    
k
# Out:
# 51

# %%
num_A
# Out:
# []
