# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('./png/find_way1.png')
img2 = mpimg.imread('./png/find_way2.png')
fig = plt.figure(figsize=(30, 30))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
nodeinfo = [[5, 3], 
            [11, 5], 
            [13, 3], 
            [3, 5], 
            [6, 1], 
            [1, 3], 
            [8, 6], 
            [7, 2], 
            [2, 2]]

# %%
tmp_max = max(nodeinfo, key=lambda k: k[1])
tmp_idx = [idx for idx,x in enumerate(nodeinfo) if x == tmp_max]
nodeinfo.remove(tmp_max)

# %%
nodeinfo
# Out:
# [[5, 3], [11, 5], [13, 3], [3, 5], [6, 1], [1, 3], [7, 2], [2, 2]]
