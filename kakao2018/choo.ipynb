# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('choo1.png')
img2 = mpimg.imread('choo2.png')
fig = plt.figure(figsize=(30, 30))
ax1 = fig.add_subplot(1,2,1)
ax1.imshow(img)
ax2 = fig.add_subplot(1,2,2)
ax2.imshow(img2)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# start : 16:52
# 응답완료시간 s   / 2016-09-15
# 처리시간 t     / 0.1s, 2s 최대 셋째 자리까지

lines = [
"2016-09-15 20:59:57.421 0.351s",
"2016-09-15 20:59:58.233 1.181s",
"2016-09-15 20:59:58.299 0.8s",
"2016-09-15 20:59:58.688 1.041s",
"2016-09-15 20:59:59.591 1.412s",
"2016-09-15 21:00:00.464 1.466s",
"2016-09-15 21:00:00.741 1.581s",
"2016-09-15 21:00:00.748 2.31s",
"2016-09-15 21:00:00.966 0.381s",
"2016-09-15 21:00:02.066 2.62s"
]

# lines = ["2016-09-15 00:00:00.000 3s"]

# lines = ["2016-09-15 01:00:04.002 2.0s"]

# lines = ["2016-09-15 01:00:04.002 2.0s", "2016-09-15 01:00:07.000 2s"]

# %%
    

def start_end_time(line):
    end_time, duration = line[11:].split(" ")
    end_time = float(end_time.replace(":", ""))
    duration = float(duration[:-1])
    start_time = end_time - duration + 0.001

    return start_time, end_time


list_time = []

for line in lines:
    start_time, end_time = start_end_time(line)
    list_time.append([start_time, end_time])

# %%
list_time = sorted(list_time)

# %%
list_time
# Out:
# [[205957.05299999999, 205958.233],
#  [205957.071, 205957.421],
#  [205957.5, 205958.299],
#  [205957.648, 205958.688],
#  [205958.17999999996, 205959.591],
#  [209998.43899999998, 210000.748],
#  [209998.999, 210000.464],
#  [209999.161, 210000.741],
#  [209999.447, 210002.066],
#  [210000.58599999998, 210000.966]]

# %%
result = []
start = 205957.421



# start기준
cnt = 0
start_ = start+1
for i,j in list_time:
    if start <= i and i <= start_:
        cnt += 1
        print(cnt, i,j)
#         continue

#         elif start <= j and j <= start_last:
#             cnt += 1
# #             print(cnt, i,j)
#     result.append(cnt)
            
#     # end기준
#     cnt = 0
#     end_first = end - 1
#     for i,j in list_time:
#         if end_first <= i and i <= end:
#             cnt += 1
#             continue
#         elif start <= j and j <= start_last:
#             cnt += 1
#     result.append(cnt)
# Out:
# 1 205957.5 205958.299
# 2 205957.648 205958.688
# 3 205958.17999999996 205959.591

# %%
result
# Out:
# [4, 4, 3, 2, 4, 4, 4, 3, 4, 3, 3, 1, 3, 0, 2, 1, 1, 0, 3, 3]

# %%
answer = max(result)

# %%
answer
# Out:
# 1

# %%
result
# Out:
# [1, 1]

# %%
list_time
# Out:
# [[10002.003, 10004.002], [10005.001, 10007.0]]

# %%
list_time
# Out:
# [[10002.003, 10004.002], [10005.001, 10007.0]]
